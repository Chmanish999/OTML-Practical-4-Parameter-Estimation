# %% [raw]
# Practical 4: Parameter Estimation
# 1. Title
#
# Understanding Parameter Estimation using Machine Learning Models

# %% [raw]
# 2. Objective
#
# After completing this practical, students will be able to:
#
# Understand the meaning of parameters in machine learning.
# Understand parameter estimation.
# Learn how ML models estimate internal rules from data.
# Connect parameter estimation with optimization.
# Understand how learning improves predictions.

# %% [raw]
# What are Parameters?
#
# Parameters are:
#
# Internal values learned by the model
#
# These values help the model make predictions.Parameter Estimation
#
# Parameter estimation means:
#
# Finding the best parameter values using training data
#
# The goal is:
#
# Best prediction
# Minimum error

# %% [raw]
# | Model             | Parameters              |
# | ----------------- | ----------------------- |
# | Linear Regression | Weights and bias        |
# | Decision Tree     | Split rules             |
# | Neural Network    | Weights                 |
# | SVM               | Hyperplane coefficients |

# %%
import pandas as pd

from sklearn.tree import DecisionTreeClassifier

from sklearn import tree

import matplotlib.pyplot as plt  



df = pd.read_csv("music1.csv")

df.head()                                                                                                                          

X = df[["age", "gender"]]

y = df["gener"]                                                                                               

model = DecisionTreeClassifier()

model.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(figsize=(12,8))

tree.plot_tree(
    model,
    feature_names=["age", "gender"],
    class_names=model.classes_,
    filled=True
)

plt.show()

# %%
sample = [[22, 1]]

prediction = model.predict(sample)

print("Predicted Genre:", prediction[0])
# Out:
# Predicted Genre: HipHop
# C:\Users\chman\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # During training, the machine learning model estimates internal decision rules from the data.
# ##These estimated parameters help the model make predictions on new inputs.

# %% [raw]
# Data
#    ↓
# Learning
#    ↓
# Parameter Estimation
#    ↓
# Prediction
